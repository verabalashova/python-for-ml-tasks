# %% [markdown]
# В цьому домашньому завданні відпрацюємо з вами знання, отримані в модулі зі статистики.
#
# **Завдання 1.** Ми обговорили з Вами на лекції, що велика літера Сігма грецького алфавіту позначає в математиці суму. Знайдіть з використанням Python $\Sigma x$, $\Sigma x^2$, та $\Sigma (x-1)^2$ для наступного набору даних:
# `1 3 4`
# Виведіть результат кожного обчислення на екран.

# %%
import numpy as np

# %%
x = [1, 2, 3]
x_sqr = [num**2 for num in x]
x_minus_one_sqr = [(num - 1)**2 for num in x]

print('Сума x[i] = ', sum(x))
print('Сума x[i]**2 = ', sum(x_sqr))
print('Сума (x[i]-1)**2 = ', sum(x_minus_one_sqr))
# Out:
# Сума x[i] =  6
# Сума x[i]**2 =  14
# Сума (x[i]-1)**2 =  5

# %% [markdown]
# **Завдання 2.** Ми зібрали дані про суму покупок в гривнях 20ма випадково обраними клієнтами в нашому магазині (всього клієнтів у нас більше) за минулий місяць. Вони представлені в змінній `sum_purchases`. Знайдіть **вибіркове середнє** для цих даних кожним з зазначених методів:
#
#   2.1. без використання жодних бібліотек, користуючись тільки Python.
#   2.2. використовуючи відповідний метод бібліотеки `numpy`.
#
#   Виведіть результат обчислень в кожному з випадків на екран та порівняйте результати. Вони співпадають?

# %%
sum_purchases = [ 316,  493,  367,  153,  224,  121,  322,  450,  196,  397,  281, 239,  484,  124,  223,  448,  432,  255, 4310, 3524]

# якщо забрати останні два елементи для більш нормального розподілу:
# sum_purchases = [ 316,  493,  367,  153,  224,  121,  322,  450,  196,  397,  281, 239,  484,  124,  223,  448,  432,  255]

sum_purchases_mean = sum(sum_purchases)/len(sum_purchases)

# %%
print('2.1. Вибіркове середнє без використання жодних бібліотек: ', sum_purchases_mean)
print('2.2. Вибіркове середнє, використовуючи відповідний метод бібліотеки `numpy`: ', np.mean(sum_purchases))
# Out:
# 2.1. Вибіркове середнє без використання жодних бібліотек:  667.95
# 2.2. Вибіркове середнє, використовуючи відповідний метод бібліотеки `numpy`:  667.95

# %% [markdown]
# **Завдання 3.** Для того ж набору даних в змінній `sum_purchases` обчисліть **медіану** кожним з зазначених методів:
#
#   3.1. без використання жодних бібліотек, користуючись тільки Python.
#   3.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран. Порівняйте результати зі значенням вибіркового середнього. Напишіть коментар, для яких задач ви б використовували вибіркове середнє, а для яких - медіану?

# %%
sorted_sum_purchases = sorted(sum_purchases)
# len(sorted_sum_purchases) == 20, Отже потрібно знайти середнє двох елементів посередині списку: 10-го і 11-го, але індекси йдлуть з 0б тому нам потрбне середнє елементів з індексом 9 і 10:
sum_purchases_median = (sorted_sum_purchases[len(sorted_sum_purchases)//2-1] + sorted_sum_purchases[len(sorted_sum_purchases)//2])/2

# %%
print('3.1. Медіана без використання жодних бібліотек: ', sum_purchases_median)
print('3.2. Медіана, використовуючи відповідний метод бібліотеки `numpy`: ', np.median(sum_purchases))

# В даному випадку початкові дані sum_purchases містять два значення, які приблоизно в 10 раз вище середнього інших значень, виходить такий вкид двох незвичних чисел, тому для таких даних краще використовувати медіану. Коли дані більш симетричні, то краще працює вибіркове середнє.
# Out:
# 3.1. Медіана без використання жодних бібліотек:  319.0
# 3.2. Медіана, використовуючи відповідний метод бібліотеки `numpy`:  319.0

# %% [markdown]
# **Завдання 4**. Обчислість стандартне відхилення наведеної вибірки в змінній `sum_purchases` кожним з зазначених методів:
#
#   4.1. без використання жодних бібліотек, користуючись тільки Python.
#   4.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран.

# %%
sum_purchases_minus_mean = [(num - sum_purchases_mean)**2 for num in sum_purchases]
std_sum_purchases_general = np.sqrt(sum(sum_purchases_minus_mean)/len(sum_purchases))
std_sum_purchases_sample = np.sqrt(sum(sum_purchases_minus_mean)/(len(sum_purchases)-1))

# %%
print('4.1. Cтандартне відхилення без використання жодних бібліотек для вибірки: ', std_sum_purchases_sample, ' і для генеральної сукупності: ', std_sum_purchases_general)
print('4.2. Cтандартне відхилення, використовуючи відповідний метод бібліотеки `numpy` для вибірки: ', np.std(sum_purchases, ddof=1), ' і для генеральної сукупності: ', np.std(sum_purchases))
# Out:
# 4.1. Cтандартне відхилення без використання жодних бібліотек для вибірки:  1124.5433447451132  і для генеральної сукупності:  1096.0692713054227
# 4.2. Cтандартне відхилення, використовуючи відповідний метод бібліотеки `numpy` для вибірки:  1124.5433447451132  і для генеральної сукупності:  1096.0692713054227

# %% [markdown]
# **Завдання 5**. Ми провели дослідження віку студентів-першокурсників. Виявилось, що
# - 10 студентів мають вік 16 років
# - 25 студентів - 17 років
# - 20 студентів - 18 років
# - 2 студенти - 20 років
#
# Обчислість середнє значення для цієї вибірки будь-яким способом - на чистому Python або з numpy - та виведіть результат на екран.

# %%
students_age = [16]*10 + [17]*25 + [18]*20 + [20]*2
# print(students_age)

print('5. Середнє значення для цієї вибірки, використовуючи відповідний метод бібліотеки `numpy`: ', np.mean(students_age))
# Out:
# 5. Середнє значення для цієї вибірки, використовуючи відповідний метод бібліотеки `numpy`:  17.280701754385966

# %% [markdown]
# **Завдання 6**. Крім даних про суму покупок, ми зібрали ще дані про кількість відвідувань кожного з кожного покупця, які знаходяться в змінній `visits`. Обчисліть коефіцієнт кореляції Пірсона для суми покупок і кількості відвідувань кожним з зазначених методів:
#
#   6.1. без використання жодних бібліотек, користуючись тільки Python.
#   6.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат на екран. Проаналізуйте результат.
#
# Виведіть додатково графік розсіювання викликавши код нижче і зробіть заключення, чи варто щось змінити при підрахунку кореляції, аби коефіцієнт Пірсона показував коректну оцінку лінійної залежності?

# %%
visits = [ 6,  2, 10,  3,  9,  9,  2,  3,  6,  6, 10,  2,  5, 10,  3,  5,  4, 7,  4,  2]

# якщо забрати останні два елементи для більш нормального розподілу:
# visits = [ 6,  2, 10,  3,  9,  9,  2,  3,  6,  6, 10,  2,  5, 10,  3,  5,  4, 7]

# %%
# рахуємо середнє для visits:
visits_mean = sum(visits)/len(visits)

# рахуємо добуток різницю між елементом і середнім значенням для кожної пари елементів `sum_purchases`` і `visits``:  
sum_purchases_vists = [(sum_purchases[i] - sum_purchases_mean)*(visits[i] - visits_mean) for i in range(len(sum_purchases))]

# рахуємо коваріацію:
cov_sum_purchases_vists = sum(sum_purchases_vists)/(len(sum_purchases)-1)

# обчислюємо стандартне відхилення для `visits`
visits_minus_mean = [(num - visits_mean)**2 for num in visits]
std_visits_sample = np.sqrt(sum(visits_minus_mean)/(len(visits)-1))

correlation_coef = cov_sum_purchases_vists / (std_sum_purchases_sample * std_visits_sample)

# %%
print('6.1. Коефіцієнт кореляції Пірсона без використання жодних бібліотек: ', correlation_coef, ' заокруглено для порівння з `numpy`: ', round(correlation_coef, 8))
print('6.2. Коефіцієнт кореляції Пірсона, використовуючи відповідний метод бібліотеки `numpy`: ', np.corrcoef(sum_purchases, visits))
# Out:
# 6.1. Коефіцієнт кореляції Пірсона без використання жодних бібліотек:  -0.30265844687666454  заокруглено для порівння з `numpy`:  -0.30265845
# 6.2. Коефіцієнт кореляції Пірсона, використовуючи відповідний метод бібліотеки `numpy`:  [[ 1.         -0.30265845]
#  [-0.30265845  1.        ]]

# %%
import matplotlib.pyplot as plt

plt.scatter(sum_purchases, visits)
plt.title('Scatter Plot of Purchases vs. Visits')
plt.xlabel('Sum of Purchases')
plt.ylabel('Number of Visits');

# %% [markdown]
# Але якщо з віхдних даних видалити два останні елементи, які дуже вибиваються з основного набору в `sum_purchases` (це елементи зі значеннями 4310, 3524), то ми отримаємо більш інформативний графік і зможемо зробюити висновок щодо кореляції
#
# ```
# sum_purchases = [ 316,  493,  367,  153,  224,  121,  322,  450,  196,  397,  281, 239,  484,  124,  223,  448,  432,  255]
# visits = [ 6,  2, 10,  3,  9,  9,  2,  3,  6,  6, 10,  2,  5, 10,  3,  5,  4, 7]
# ```

# %% [markdown]
# **Завдання 7**. В попередньому завданні ми помітили, що викиди нам заважають отримати "правдиве" значення кореляції. Давайте вилучимо записи, які відповідають значенням з викидами в сумі покупок і обчисліть коеф. кореляції. Для цього поставте `threshold`, який дорінює середньому значенню + 2 стандартних вдіхилля суми покупок і всі значення, які більше за нього, будемо вважати викидами (є і інші правила для визначення викидів - з ним и познайомимось пізніше).
#
# Вилучіть значення з обох масивів і обчисліть коеф. кореляції Пірсона з допомогою `numpy` для кількості візитів і суми покупок без записів-викидів. Виведіть результат на екран, побудуйте діаграму розсіювання і проаналізуйте результат: що можемо сказати про залежність в даних?

# %%
threshold = sum_purchases_mean + 2 * std_sum_purchases_sample

print ('Поріг допустимих значень: ', threshold)

sum_purchases_new = []
visits_new = []

for index, el in enumerate(sum_purchases):
    if el < threshold:
        sum_purchases_new.append(el)
        visits_new.append(visits[index])

print('Оновлені вхідні дані:')
print(sum_purchases_new)
print(visits_new)


print('7. Коефіцієнт кореляції Пірсона після вилучення викидів: ', np.corrcoef(sum_purchases_new, visits_new))
plt.scatter(sum_purchases_new, visits_new)
plt.title('Scatter Plot of Purchases vs. Visits')
plt.xlabel('Sum of Purchases')
plt.ylabel('Number of Visits');
# Out:
# Поріг допустимих значень:  2917.0366894902263
# Оновлені вхідні дані:
# [316, 493, 367, 153, 224, 121, 322, 450, 196, 397, 281, 239, 484, 124, 223, 448, 432, 255]
# [6, 2, 10, 3, 9, 9, 2, 3, 6, 6, 10, 2, 5, 10, 3, 5, 4, 7]
# 7. Коефіцієнт кореляції Пірсона після вилучення викидів:  [[ 1.         -0.36852121]
#  [-0.36852121  1.        ]]
